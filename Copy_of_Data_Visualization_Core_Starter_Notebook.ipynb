# %% [markdown]
# <a href="https://colab.research.google.com/github/NatumanyaDuncan/Prediction_of_Products_Sales/blob/main/Copy_of_Data_Visualization_Core_Starter_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization Core

# %% [markdown]
# - Student Name: Natumanya Duncan

# %% [markdown]
# ## Import Packages and Load Data

# %%
# import the required packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Save the filepath to the data as a variable "fpath"
fpath = '/content/drive/MyDrive/week 3/insurance_mod (1).csv'
df = pd.read_csv(fpath)
df
# Out:
#       age     sex     bmi  children  smoker     region  charges
# 0      19  female  27.900         0       1  southwest  16885.0
# 1      18    male  33.770         1       0  southeast   1726.0
# 2      28    male  33.000         3       0  southeast   4449.0
# 3      33    male  22.705         0       0  northwest  21984.0
# 4      32    male  28.880         0       0  northwest   3867.0
# ...   ...     ...     ...       ...     ...        ...      ...
# 1333   50    male  30.970         3       0  northwest  10601.0
# 1334   18  female  31.920         0       0  northeast   2206.0
# 1335   18  female  36.850         0       0  southeast   1630.0
# 1336   21  female  25.800         0       0  southwest   2008.0
# 1337   61  female  29.070         0       1  northwest  29141.0
#
# [1338 rows x 7 columns]

# %%
# Read in the file and disply the info and head
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 73.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 73.3+ KB

# %% [markdown]
# ## Explore Correlation

# %% [markdown]
# ### 1\) Correlation Heatmap

# %% [markdown]
# 1a) Define a variable containing the correlations between variables in the insurance dataset.

# %%
# Find correlations

correlation_matrix = df.corr()

print(correlation_matrix)
# Out:
#                age       bmi  children    smoker   charges
# age       1.000000  0.109272  0.042469 -0.025019  0.299009
# bmi       0.109272  1.000000  0.012759  0.003750  0.198341
# children  0.042469  0.012759  1.000000  0.007673  0.067997
# smoker   -0.025019  0.003750  0.007673  1.000000  0.787251
# charges   0.299009  0.198341  0.067997  0.787251  1.000000
# <ipython-input-10-13a30fcc0542>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# 1b) Make a heatmap of the correlations and annote with the values.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap with Annotations')
plt.show()
# Out:
# <ipython-input-12-74a675bee0ed>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# 1c) **Are there arny strong correlations?
# Is it a positive or negative correlation?**
#
# - Your Answer:
#   - `...`Postive correlation

# %% [markdown]
# ## Explore Charges vs. Smokers

# %% [markdown]
# ### 2\) Barplot - Charges for Smokers vs. Non-Smokers

# %% [markdown]
# 2a) Make a barplot to visualize the mean of charges for smokers and nonsmokers.

# %%
# Make a barplot of smoker vs charges
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='smoker', y='charges', ci=None)
plt.xlabel('Smoker')
plt.ylabel('Mean Charges')
plt.title('Mean Charges for Smokers and Nonsmokers')
plt.xticks([0, 1], ['Nonsmoker', 'Smoker'])
plt.show()
# Out:
# <ipython-input-13-a57b986d0417>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='smoker', y='charges', ci=None)

# %% [markdown]
# 2b) Is the mean of charges higher for smokers or nonsmokers? ((In a future course, you will explore how to calculate the statistical significance of this difference)
#
# - Your Answer:
#   -  `...`nonsmokers

# %% [markdown]
# ### 3\) Boxplot - Charges for Smokers vs. Non-Smokers

# %% [markdown]
# 3a) Create a boxplot with x as smokers and y as charges.

# %%
# Create a boxplot of smoker vs. charges
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='smoker', y='charges')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.title('Boxplot of Charges for Smokers and Nonsmokers')
plt.xticks([0, 1], ['Nonsmoker', 'Smoker'])
plt.show()

# %% [markdown]
# 3b) What information does this include that you could not see in your bar chart?
# - Answer(s):
#   - `...`Central Tendency and Spread,
#   Outliers

# %% [markdown]
# ## Explore Charges for Males vs. Females

# %% [markdown]
# ### 4\) Barplot - Charges for Males vs. Females

# %% [markdown]
# 4a) Make a searborn barplot to visualize the difference in charges between males and females.

# %%
# Make a barplot of sex vs. charges
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='sex', y='charges', ci=None)
plt.xlabel('Sex')
plt.ylabel('Charges')
plt.title('Difference in Charges between Males and Females')
plt.show()
# Out:
# <ipython-input-15-62297e7d4b74>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='sex', y='charges', ci=None)

# %% [markdown]
# 4b)  Is the mean of charges higher for males or females?
#
# - Your Answer:
#   - `...`males

# %% [markdown]
# ### 5\) Grouped Barplot - Charges by Sex and Smoker

# %% [markdown]
# 5a\) Create a seaborn barplot to visualize the diference between insurance charges grouped by Smoker (on the x-axis), and Sex (the hue).

# %%
# Create a barplot of smoker vs charges, colored by sex
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='smoker', y='charges', hue='sex', ci=None)
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.title('Difference in Insurance Charges by Smoker and Sex')
plt.xticks([0, 1], ['Nonsmoker', 'Smoker'])
plt.legend(title='Sex')
plt.show()
# Out:
# <ipython-input-16-34f61f222bf4>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='smoker', y='charges', hue='sex', ci=None)

# %% [markdown]
# 5b\) What do you observe? Which of the 4 groups has the highest average charges?
# - Your Answer:
#   - `...`male, Smoker

# %% [markdown]
# ## Explore Age vs. Charges

# %% [markdown]
# ### 6\) Scatter Plot - Age vs. Charges

# %% [markdown]
# 6a) Make a scatterplot to visualize the relationship between charges and age for the entire dataset

# %%
# Create a scatter plot of age vs charges
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Relationship between Charges and Age')
plt.show()

# %% [markdown]
# 6b) Desribe what you notice from the visualization.
# - Your Answer:
#   - `...`The scatterplot suggests that while there is some variability in charges across different age groups, the relationship between age and charges is not linear or straightforward.

# %% [markdown]
# ### 7\)  Grouped Scatter Plot - Age vs. Charges, colored by Smoker

# %% [markdown]
# 7a) Make a scatterplot to visualize the relationship between charges and age, but colored by smoker or not.

# %%
# make another scatterplot of age vs charges, but colored by smoker
# (using seaborn will make this easy)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='charges', hue='smoker')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Relationship between Charges and Age, Colored by Smoker')
plt.legend(title='Smoker', labels=['Non-Smoker', 'Smoker'])
plt.show()

# %% [markdown]
# 7b) Desribe what you notice from the visualization.

# %% [markdown]
# - Your Answer:
#   - `...`there is an increase in visualisation due to addition of colors

# %% [markdown]
# ### 8\) Grouped Scatter Plot - Age vs. Charges, colored by Sex

# %% [markdown]
# 8a) Make a scatterplot to visualize the relationship between charges and age, but colored by sex.

# %%
# make another scatterplot of charges vs age, but this time color the dots by sex
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='charges', hue='sex')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Relationship between Charges and Age, Colored by Sex')
plt.legend(title='Sex', labels=['Male', 'Female'])
plt.show()

# %% [markdown]
# 8b) Describe what you notice from the visualization
#
# - Your Answer:
#   - `...` The scatterplot shows that charges and age are distributed differently between males and females. There is some overlapping of points, but there are also areas where charges and age are more concentrated for each sex.

# %% [markdown]
# ## Explore BMI

# %% [markdown]
# ### 9\) Regplot - Charges vs. BMI

# %% [markdown]
# 9a) Make a seaborn regplot to visualize the relationship between charges and bmi for the entire dataset

# %%
# Make a seaborn regplot for bmi vs. charges.
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='bmi', y='charges', scatter_kws={'alpha':0.5})
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.title('Relationship between Charges and BMI')
plt.show()

# %% [markdown]
# 9b\) What do you notice from the visualization? *(There are many correct answers.)*
#
# - Your Answer:
#   - `...`There is a generally positive linear trend between charges and BMI.
#        While the trend is positive, there is significant variability in charges for each BMI value.

# %% [markdown]
# ### 10\) Scatterplot - Charges vs. BMI - Colored by Smoker

# %% [markdown]
# 10a) Make a scatterplot to visualize the relationship between charges and bmi colored by smoker or not

# %%
# Make a scatterplot of bmi vs charges, colored by smoker
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='bmi', y='charges', hue='smoker', alpha=0.7)
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.title('Relationship between Charges and BMI, Colored by Smoker')
plt.legend(title='Smoker', labels=['Non-Smoker', 'Smoker'])
plt.show()

# %% [markdown]
# 10b) What do you notice from the visualization? (There are many correct answers.)
#
# - Your Answer:
#   - `...`The plot shows that smokers (designated by one color) generally have higher charges compared to non-smokers (designated by another color), regardless of their BMI.
#
#   Within both smoker and non-smoker groups, there is a positive linear trend between charges and BMI. As BMI increases, charges tend to increase.

# %% [markdown]
# ### 11\)  Linear Model Plot - Charges vs. BMI - Colored by Smoker

# %% [markdown]
# 11a) Compare the relationship of bmi and charges for smokers and nonsmokers using seaborn's `lmplot` to calculate a separate trendline for Smokers vs. Non-Smokers.

# %%
# Create an lmplot of bmi vs. charges, colored by smoker.
plt.figure(figsize=(10, 6))
sns.lmplot(data=df, x='bmi', y='charges', hue='smoker', markers=['o', 'x'], scatter_kws={'alpha': 0.7})
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.title('Linear Relationship between BMI and Charges, Colored by Smoker')
plt.legend(title='Smoker', labels=['Non-Smoker', 'Smoker'])
plt.show()

# %% [markdown]
# 11b) What do you notice from the visualization? (Compare the trendlines.)
#
# - Your Answer:
#   - `...`The trendline for smokers is significantly steeper compared to that of non-smokers. This indicates that the increase in charges per unit increase in BMI is much more pronounced for smokers than for non-smokers.
#
#   The steeper slope of the trendline for smokers suggests a stronger positive correlation between BMI and charges among smokers. In other words, for smokers, an increase in BMI is associated with a larger increase in charges compared to non-smokers

# %% [markdown]
# ## Explore Regions

# %% [markdown]
# ### 12\) Countplot for Regions

# %% [markdown]
# 12a) Make a countplot to show how many customers per region.

# %%
# Make a countplot for region
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='region')
plt.xlabel('Region')
plt.ylabel('Number of Customers')
plt.title('Distribution of Customers per Region')
plt.show()

# %% [markdown]
# 12b) Which region appears the most in this data set?
#
# - Your Answer:
#   - `...`southeast

# %% [markdown]
# ### 13\) Barplot of Charges by Region

# %% [markdown]
# 13a) Make a barplot to show average charges by region.

# %%
# make a barplot of charges by region
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='region', y='charges')
plt.xlabel('Region')
plt.ylabel('Average Charges')
plt.title('Average Charges by Region')
plt.show()

# %% [markdown]
# 13b) Which region has the highest average charges?
#
# - Your Answer:
#   - `...`southeast

# %% [markdown]
# ### 14\) Bar Chart of Ratios (%) of Smokers in Each Region

# %% [markdown]
# 14a) Calculate the ratio of smokers in each region and save it as a variable called "percent_smoker_by_region". (Hint: use .groupby with "region" combined with slicing the "smoker" column and end with .mean() )

# %%
percent_smoker_by_region = df.groupby('region')['smoker'].mean()

print(percent_smoker_by_region)
# Out:
# region
# northeast    0.206790
# northwest    0.178462
# southeast    0.250000
# southwest    0.178462
# Name: smoker, dtype: float64

# %% [markdown]
# 14b) Plot the ratios of smokers by region as a bar plot.

# %%
# Plot the ratios (the results of then groupby above)
percent_smoker_by_region = df.groupby('region')['smoker'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=percent_smoker_by_region.index, y=percent_smoker_by_region.values)
plt.xlabel('Region')
plt.ylabel('Percentage of Smokers')
plt.title('Percentage of Smokers by Region')
plt.show()

# %% [markdown]
# 14c) Which region has the highest ratio of smokers?
#
# - Your Answer:
#   - `...`southeast

# %% [markdown]
# > You've completed the assignment! Download your notebook and upload it as your submission.
